# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv',)
data_fighter_ratios = data.copy()
data.head(5)
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0           0.0  ...                            0                1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Columns: 144 entries, R_fighter to R_age
# dtypes: bool(1), float64(106), int64(28), object(9)
# memory usage: 6.6+ MB

# %%
data.describe()
# Out:
#           B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# count  4585.000000   4585.000000        4585.000000            4585.000000
# mean      0.247476      0.176818           0.453310               0.434290
# std       0.378509      0.324633           0.130458               0.132618
# min       0.000000      0.000000           0.000000               0.000000
# 25%       0.000000      0.000000           0.376489               0.351045
# 50%       0.015625      0.000000           0.450000               0.427500
# 75%       0.500000      0.250000           0.527500               0.510000
# max       5.000000      3.000000           1.000000               1.000000
#
#        B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# count   4585.000000       4585.000000    4585.000000        4585.000000
# mean       0.292650          0.268742       0.478884           0.409276
# std        0.273628          0.267178       0.724229           0.653826
# ...

# %%
data.describe(include = np.object)
# Out:
# /var/folders/s4/hm1fhwcn6_j3p3p9dbbynysh0000gn/T/ipykernel_79321/2743208382.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.describe(include = np.object)
#          R_fighter        B_fighter    Referee        date  \
# count         6012             6012       5980        6012
# unique        1514             1987        204         550
# top     Jim Miller  Jeremy Stephens  Herb Dean  2016-11-19
# freq            27               21        858          25
#
#                       location Winner weight_class  B_Stance  R_Stance
# count                     6012   6012         6012      5946      5983
# unique                     166      3           14         5         5
# ...

# %%
data.R_fighter.value_counts()
# Out:
# Jim Miller           27
# Donald Cerrone       24
# Andrei Arlovski      24
# Diego Sanchez        24
# Demian Maia          24
#                      ..
# Guido Cannetti        1
# Humberto Bandenay     1
# Nad Narimani          1
# Ednaldo Oliveira      1
# Scott Morris          1
# Name: R_fighter, Length: 1514, dtype: int64

# %%
data.B_fighter.value_counts()
# Out:
# Jeremy Stephens     21
# Charles Oliveira    19
# Nik Lentz           15
# Rafael Dos Anjos    14
# Tim Boetsch         13
#                     ..
# James Hammortree     1
# Nicco Montano        1
# Paul Daley           1
# Renzo Gracie         1
# Sean Daugherty       1
# Name: B_fighter, Length: 1987, dtype: int64

# %%
red_wins = np.sum(data['Winner'] == "Red")

blue_wins = np.sum(data['Winner'] == "Blue")

print("Red wins: " + str(red_wins) + ", Blue wins: " + str(blue_wins))
# Out:
# Red wins: 3979, Blue wins: 1923

# %%
data.weight_class.value_counts()
# Out:
# Lightweight           1091
# Welterweight          1083
# Middleweight           813
# Heavyweight            585
# LightHeavyweight       573
# Featherweight          551
# Bantamweight           475
# Flyweight              230
# WomenStrawweight       192
# WomenBantamweight      151
# WomenFlyweight         112
# OpenWeight              86
# CatchWeight             54
# WomenFeatherweight      16
# Name: weight_class, dtype: int64

# %%
data.loc[:,"R_Stance"].unique()
# Out:
# array(['Orthodox', 'Southpaw', 'Switch', nan, 'Open Stance', 'Sideways'],
#       dtype=object)

# %%
data.loc[:,"B_Stance"].unique()
# Out:
# array(['Orthodox', 'Southpaw', 'Switch', nan, 'Open Stance', 'Sideways'],
#       dtype=object)

# %%
stance_df = pd.DataFrame(pd.concat([data.R_Stance, data.B_Stance]))
stance_df.head()
# Out:
#           0
# 0  Orthodox
# 1  Orthodox
# 2  Southpaw
# 3    Switch
# 4  Orthodox

# %%
stance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12024 entries, 0 to 6011
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       11929 non-null  object
# dtypes: object(1)
# memory usage: 187.9+ KB

# %%
stance_df.describe()
# Out:
#                0
# count      11929
# unique         5
# top     Orthodox
# freq        9068

# %%
stance_df[0].value_counts()
# Out:
# Orthodox       9068
# Southpaw       2396
# Switch          435
# Open Stance      24
# Sideways          6
# Name: 0, dtype: int64

# %%
stance_df.isna().sum()
# Out:
# 0    95
# dtype: int64

# %%
plt.figure(figsize = (15,8))
sns.set(font_scale = 1)
sns.countplot(data = stance_df, x = stance_df[0])
plt.xlabel("Stance", fontsize = 14)
plt.ylabel("Frequency",fontsize = 14)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
bstance_age = data.loc[:, ("B_Stance", "B_age")]
bstance_age.head()
# Out:
#    B_Stance  B_age
# 0  Orthodox   31.0
# 1  Orthodox   32.0
# 2  Orthodox   32.0
# 3  Southpaw   28.0
# 4  Orthodox   29.0

# %%
bstance_age.rename(axis=1, mapper={"B_Stance" : "Stance", "B_age" : "Age"}, inplace=True)
bstance_age.head()
# Out:
#      Stance   Age
# 0  Orthodox  31.0
# 1  Orthodox  32.0
# 2  Orthodox  32.0
# 3  Southpaw  28.0
# 4  Orthodox  29.0

# %%
rstance_age = data.loc[:, ("R_Stance", "R_age")]
rstance_age.head()
# Out:
#    R_Stance  R_age
# 0  Orthodox   27.0
# 1  Orthodox   28.0
# 2  Southpaw   28.0
# 3    Switch   25.0
# 4  Orthodox   43.0

# %%
rstance_age.rename(axis=1, mapper={"R_Stance" : "Stance", "R_age" : "Age"}, inplace=True)
rstance_age.head()
# Out:
#      Stance   Age
# 0  Orthodox  27.0
# 1  Orthodox  28.0
# 2  Southpaw  28.0
# 3    Switch  25.0
# 4  Orthodox  43.0

# %%
stance_age_df = bstance_age.append(rstance_age)
# Out:
# /var/folders/s4/hm1fhwcn6_j3p3p9dbbynysh0000gn/T/ipykernel_79321/180656494.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stance_age_df = bstance_age.append(rstance_age)

# %%
stance_age_df.dropna(inplace = True)

# %%
plt.figure(figsize=(15,8))
sns.set(font_scale=1.5)
sns.swarmplot(data = stance_age_df, x = "Stance", y = "Age", dodge = True)
plt.show()
# Out:
# /Users/jasonmay-suzuki/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 93.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/jasonmay-suzuki/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 79.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/jasonmay-suzuki/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 26.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/jasonmay-suzuki/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 94.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
r_age_streak = data.loc[:, ("R_age", "R_longest_win_streak")]
r_age_streak.head()
# Out:
#    R_age  R_longest_win_streak
# 0   27.0                     1
# 1   28.0                     2
# 2   28.0                     3
# 3   25.0                     0
# 4   43.0                     2

# %%
b_age_streak = data.loc[:, ("B_age", "B_longest_win_streak")]
b_age_streak.head()
# Out:
#    B_age  B_longest_win_streak
# 0   31.0                     1
# 1   32.0                     2
# 2   32.0                     0
# 3   28.0                     0
# 4   29.0                     3

# %%
r_age_streak.rename(axis= 1, mapper = {'R_age':"Age", "R_longest_win_streak" : "Win_streak"}, inplace=True)
r_age_streak.head()
# Out:
#     Age  Win_streak
# 0  27.0           1
# 1  28.0           2
# 2  28.0           3
# 3  25.0           0
# 4  43.0           2

# %%
b_age_streak.rename(axis= 1, mapper = {'B_age':"Age", "B_longest_win_streak" : "Win_streak"}, inplace=True)
b_age_streak.head()
# Out:
#     Age  Win_streak
# 0  31.0           1
# 1  32.0           2
# 2  32.0           0
# 3  28.0           0
# 4  29.0           3

# %%
age_streak_df = pd.concat([r_age_streak, b_age_streak])
age_streak_df.head()
# Out:
#     Age  Win_streak
# 0  27.0           1
# 1  28.0           2
# 2  28.0           3
# 3  25.0           0
# 4  43.0           2

# %%
age_streak_df.dropna(inplace = True)

# %%
age_streak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11789 entries, 0 to 6011
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         11789 non-null  float64
#  1   Win_streak  11789 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 276.3 KB

# %%
plt.figure(figsize=(15,8))
sns.set(font_scale=1.4)
sns.heatmap(age_streak_df.corr(), annot= True, cmap = "Blues")
plt.show()

# %%
age_series = pd.concat([data.B_age, data.R_age])
age_series.head(10)
# Out:
# 0    31.0
# 1    32.0
# 2    32.0
# 3    28.0
# 4    29.0
# 5    27.0
# 6    35.0
# 7    28.0
# 8    29.0
# 9    24.0
# dtype: float64

# %%
age_bins = pd.cut(x=age_series, bins=[0, 35, 100], labels=["Below 35", "Above 35"])

# %%
plt.figure(figsize = (15,8))
sns.set(font_scale = 1.5)
sns.countplot(x = age_bins)
plt.ylabel('Frequency')
plt.show()

# %%
b_sig_str_stats = data.loc[:, ("B_avg_SIG_STR_att", "B_avg_SIG_STR_landed")]
b_sig_str_stats.head()
# Out:
#    B_avg_SIG_STR_att  B_avg_SIG_STR_landed
# 0            50.0000               20.0000
# 1            65.5000               35.0000
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4           109.1875               57.9375

# %%
r_sig_str_stats = data.loc[:, ("R_avg_SIG_STR_att", "R_avg_SIG_STR_landed")]
r_sig_str_stats.head()
# Out:
#    R_avg_SIG_STR_att  R_avg_SIG_STR_landed
# 0          34.000000             17.000000
# 1          77.562500             43.156250
# 2          59.234375             30.375000
# 3                NaN                   NaN
# 4         109.331055             44.362305

# %%
b_sig_str_stats.rename(axis=1, mapper={"B_avg_SIG_STR_att" : "Strikes_attempted", "B_avg_SIG_STR_landed" : "Strikes_landed"}, inplace=True)
b_sig_str_stats.head()
# Out:
#    Strikes_attempted  Strikes_landed
# 0            50.0000         20.0000
# 1            65.5000         35.0000
# 2                NaN             NaN
# 3                NaN             NaN
# 4           109.1875         57.9375

# %%
r_sig_str_stats.rename(axis=1, mapper={"R_avg_SIG_STR_att" : "Strikes_attempted", "R_avg_SIG_STR_landed" : "Strikes_landed"}, inplace=True)
r_sig_str_stats.head()
# Out:
#    Strikes_attempted  Strikes_landed
# 0          34.000000       17.000000
# 1          77.562500       43.156250
# 2          59.234375       30.375000
# 3                NaN             NaN
# 4         109.331055       44.362305

# %%
sign_stats_df = pd.DataFrame(pd.concat([b_sig_str_stats, r_sig_str_stats]))
sign_stats_df.head()
# Out:
#    Strikes_attempted  Strikes_landed
# 0            50.0000         20.0000
# 1            65.5000         35.0000
# 2                NaN             NaN
# 3                NaN             NaN
# 4           109.1875         57.9375

# %%
data.corr()
# Out:
# /var/folders/s4/hm1fhwcn6_j3p3p9dbbynysh0000gn/T/ipykernel_79321/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                        title_bout  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# title_bout               1.000000  0.099967     -0.056049           0.083308
# B_avg_KD                 0.099967  1.000000     -0.104747           0.136838
# B_avg_opp_KD            -0.056049 -0.104747      1.000000          -0.130582
# B_avg_SIG_STR_pct        0.083308  0.136838     -0.130582           1.000000
# B_avg_opp_SIG_STR_pct   -0.095428 -0.156778      0.190190          -0.037459
# ...                           ...       ...           ...                ...
# R_Height_cms             0.004768  0.078261      0.096080           0.082542
# ...

# %%
bluewinner_df = data

# %%
(data.Winner=="Blue").astype(int)
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 6007    0
# 6008    0
# 6009    0
# 6010    0
# 6011    0
# Name: Winner, Length: 6012, dtype: int64

# %%
bluewinner_df["Winner"] = (data.Winner=="Blue").astype(int)

# %%
corr_bluewinner = bluewinner_df.corr().fillna(0)
corr_bluewinner
# Out:
# /var/folders/s4/hm1fhwcn6_j3p3p9dbbynysh0000gn/T/ipykernel_79321/1762998898.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_bluewinner = bluewinner_df.corr().fillna(0)
#                      Winner  title_bout  B_avg_KD  B_avg_opp_KD  \
# Winner             1.000000   -0.071307  0.015100     -0.045375
# title_bout        -0.071307    1.000000  0.099967     -0.056049
# B_avg_KD           0.015100    0.099967  1.000000     -0.104747
# B_avg_opp_KD      -0.045375   -0.056049 -0.104747      1.000000
# B_avg_SIG_STR_pct  0.009090    0.083308  0.136838     -0.130582
# ...                     ...         ...       ...           ...
# R_Height_cms      -0.068276    0.004768  0.078261      0.096080
# R_Reach_cms       -0.059089    0.019804  0.098795      0.079884
# ...

# %%
corr_bluewinner_copy = corr_bluewinner['Winner'].copy()
corr_bluewinner_copy.sort_values(inplace=True, ascending=False)
corr_bluewinner_copy
print(data_fighter_ratios)
# Out:
#           R_fighter           B_fighter        Referee        date  \
# 0      Adrian Yanez       Gustavo Lopez  Chris Tognoni  2021-03-20
# 1      Trevin Giles       Roman Dolidze      Herb Dean  2021-03-20
# 2       Tai Tuivasa     Harry Hunsucker      Herb Dean  2021-03-20
# 3     Cheyanne Buys   Montserrat Conejo     Mark Smith  2021-03-20
# 4     Marion Reneau       Macy Chiasson     Mark Smith  2021-03-20
# ...             ...                 ...            ...         ...
# 6007  Remco Pardoel  Alberta Cerra Leon  John McCarthy  1994-03-11
# 6008   Orlando Wiet    Robert Lucarelli  John McCarthy  1994-03-11
# 6009  Johnny Rhodes       David Levicki  John McCarthy  1994-03-11
# 6010  Patrick Smith          Ray Wizard  John McCarthy  1994-03-11
# 6011   Scott Morris      Sean Daugherty  John McCarthy  1994-03-11
#
#                     location Winner  title_bout       weight_class  B_avg_KD  \
# 0     Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# ...
